# %%
# import dependencies
import pandas as pd
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy

# %%
# random lats and lngs
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-80, 180, 2000)
coordinates = zip(lats, lngs)

# %%
# find nearest citis
cities = list(set([citipy.nearest_city(coordinate[0],coordinate[1]).city_name for coordinate in coordinates]))
len(cities)
# Out:
# 785

# %%
cities
# Out:
# ['jomalig',
#  'kabinda',
#  'amderma',
#  'sassandra',
#  'navalmoral de la mata',
#  'kachiry',
#  'kruisfontein',
#  'nouakchott',
#  'cape town',
#  'batsfjord',
#  'vao',
#  'ipubi',
#  'qaanaaq',
#  'sobolevo',
#  'muzaffargarh',
#  'podyuga',
#  'lethem',
#  'bonthe',
#  'jaciara',
#  'praya',
#  'ardakan',
#  'luyang',
#  'nsawam',
#  'evensk',
#  'veraval',
#  'dikson',
#  'oussouye',
#  'khasan',
#  'rio gallegos',
#  'potiskum',
#  'stornoway',
#  'pangnirtung',
#  'ilesha',
#  'juifang',
#  'ulundi',
#  'hirara',
#  'hvammstangi',
#  'neryungri',
#  'thoen',
#  'isparta',
#  'pozo colorado',
#  'qorveh',
#  'lata',
#  'adre',
#  'tarancon',
#  'turbat',
#  'arraial do cabo',
#  'baruun-urt',
#  'bolshoy uluy',
#  'ibra',
#  'gayeri',
#  'beringovskiy',
#  'tasiilaq',
#  'baffa',
#  'yabelo',
#  'behshahr',
#  'rocha',
#  'anzio',
#  'kutum',
#  'roma',
#  'georgetown',
#  'manakara',
#  'noshiro',
#  'cherskiy',
#  'road town',
#  'burgos',
#  'saint-pierre',
#  'ambulu',
#  'olafsvik',
#  'tumannyy',
#  'tilichiki',
#  'kathu',
#  'rajula',
#  'armilla',
#  'huangnihe',
#  'thurso',
#  'ancud',
#  'murgab',
#  'bujaru',
#  'parakai',
#  'senneterre',
#  'gap',
#  'bennington',
#  'karwar',
#  'kiunga',
#  'galesong',
#  'tazovskiy',
#  'ilulissat',
#  'gagarin',
#  'norrtalje',
#  'keuruu',
#  'kibala',
#  'katobu',
#  'virginia beach',
#  'yerbogachen',
#  'perth',
#  'bid',
#  'hofn',
#  'hobart',
#  'remedios',
#  'anadyr',
#  'nizhniy tsasuchey',
#  'puteyets',
#  'muroto',
#  'walvis bay',
#  'unai',
#  'poya',
#  'the valley',
#  'morondava',
#  'bredasdorp',
#  'qaqortoq',
#  'clyde river',
#  'khatanga',
#  'porto santo',
#  'katherine',
#  'padang',
#  'taoudenni',
#  'umm lajj',
#  'vostok',
#  'itarema',
#  'husavik',
#  'kholodnyy',
#  'crixas',
#  'odweyne',
#  'anloga',
#  'vila do maio',
#  'kuytun',
#  'paamiut',
#  'birao',
#  'lagoa',
#  'barra do garcas',
#  'khandyga',
#  'mayumba',
#  'linxia',
#  'puerto maldonado',
#  'esperance',
#  'lusambo',
#  'tuy hoa',
#  'lourdes',
#  'luanda',
#  'cidreira',
#  'namatanai',
#  'boden',
#  'balatonboglar',
#  'zhaotong',
#  'richards bay',
#  'dera ghazi khan',
#  'gigmoto',
#  'sangar',
#  'rovaniemi',
#  'dudinka',
#  'labuan',
#  'polovinnoye',
#  'lorengau',
#  'shepsi',
#  'poso',
#  'krasnoufimsk',
#  'cockburn town',
#  'korla',
#  'mtsensk',
#  'chapais',
#  'arroyo',
#  'nohar',
#  'omboue',
#  'sibolga',
#  'keetmanshoop',
#  'toropets',
#  'novorozhdestvenskaya',
#  'jedrzejow',
#  'mareeba',
#  'preobrazheniye',
#  'caravelas',
#  'biak',
#  'torbay',
#  'wazzan',
#  'port hedland',
#  'nikolsk',
#  'laguna',
#  'mangrol',
#  'vucje',
#  'bambous virieux',
#  'gao',
#  'luganville',
#  'oranjemund',
#  'saint-augustin',
#  'puerto ayacucho',
#  'siena',
#  'belushya guba',
#  'tunduru',
#  'byron bay',
#  'sola',
#  'saquena',
#  'sentyabrskiy',
#  'maghama',
#  'salinopolis',
#  'nepalganj',
#  'shakiso',
#  'viedma',
#  'lagos',
#  'dekar',
#  'ahipara',
#  'senanga',
#  'negrar',
#  'nouadhibou',
#  'doha',
#  'scarborough',
#  'souillac',
#  'svetlogorsk',
#  'kavaratti',
#  'lebu',
#  'maniitsoq',
#  'gat',
#  'thano bula khan',
#  'faya',
#  'jaque',
#  'ampanihy',
#  'nantucket',
#  'zhangye',
#  'tarudant',
#  'jian',
#  'itacarambi',
#  'banda aceh',
#  'altay',
#  'serebryansk',
#  'killybegs',
#  'attawapiskat',
#  'salalah',
#  'ust-barguzin',
#  'uglovskoye',
#  'kapit',
#  'asau',
#  'san lawrenz',
#  'quillota',
#  'megion',
#  'buraydah',
#  'jamestown',
#  'hvide sande',
#  'marsa matruh',
#  'erzin',
#  'mehamn',
#  'narsaq',
#  'ostrovnoy',
#  'naze',
#  'mananjary',
#  'marcona',
#  'la rioja',
#  'bulaevo',
#  'mezen',
#  'lakes entrance',
#  'leua',
#  'severo-kurilsk',
#  'zastron',
#  'surt',
#  'carutapera',
#  'bam',
#  'pando',
#  'mildura',
#  'mercedes',
#  'afua',
#  'torres',
#  'tiksi',
#  'soe',
#  'cravo norte',
#  'chifeng',
#  'jumla',
#  'robertsport',
#  'vardo',
#  'tamworth',
#  'piopio',
#  'maraa',
#  'polunochnoye',
#  'rudnaya pristan',
#  'northam',
#  'kysyl-syr',
#  'tacoronte',
#  'mnogovershinnyy',
#  'diu',
#  'bosaso',
#  'bagdarin',
#  'kloulklubed',
#  'dyadkovskaya',
#  'sencha',
#  'phan rang',
#  'le port',
#  'sao filipe',
#  'berberati',
#  'bentiu',
#  'nokaneng',
#  'zaysan',
#  'arman',
#  'weligama',
#  'visby',
#  'lodeynoye pole',
#  'konevo',
#  'joshimath',
#  'shubarshi',
#  'ribeira grande',
#  'kijang',
#  'illapel',
#  'dubovka',
#  'skibbereen',
#  'umzimvubu',
#  'hurghada',
#  'kamenka',
#  'stromness',
#  'umtata',
#  'general roca',
#  'podgornoye',
#  'halifax',
#  'sao jose da coroa grande',
#  'kpandae',
#  'panguna',
#  'goderich',
#  'port lincoln',
#  'gurupa',
#  'hinckley',
#  'illoqqortoormiut',
#  'kaeo',
#  'shahr-e kord',
#  'puerto carreno',
#  'baykit',
#  'cerrito',
#  'port augusta',
#  'oytal',
#  'kansanshi',
#  'hue',
#  'bousso',
#  'kortkeros',
#  'menongue',
#  'harper',
#  'karratha',
#  'hobyo',
#  'calvinia',
#  'ko samui',
#  'santa cruz',
#  'vila',
#  'talnakh',
#  'ust-kamchatsk',
#  'tuatapere',
#  'nizhneyansk',
#  'yuzhno-kurilsk',
#  'belozerskoye',
#  'mastic beach',
#  'shingu',
#  'porangatu',
#  'geraldton',
#  'zhigansk',
#  'kribi',
#  'baoning',
#  'tiznit',
#  'samarai',
#  'chingola',
#  'ust-koksa',
#  'marovoay',
#  'bandarbeyla',
#  'tolaga bay',
#  'barawe',
#  'mackay',
#  'vitoria',
#  'vigrestad',
#  'amapa',
#  'balaguer',
#  'lodwar',
#  'ybbs',
#  'sur',
#  'sokoni',
#  'bauchi',
#  'port macquarie',
#  'howard springs',
#  'mecca',
#  'merauke',
#  'purpe',
#  'barentu',
#  'gornoye loo',
#  'ramhormoz',
#  'port alfred',
#  'ayr',
#  'lumut',
#  'garchitorena',
#  'kangaatsiaq',
#  'suzu',
#  'machiques',
#  'maragogi',
#  'tidore',
#  'verkhoshizhemye',
#  'yulara',
#  'jalu',
#  'havre-saint-pierre',
#  'gouyave',
#  'pantai remis',
#  'catamarca',
#  'ayios matthaios',
#  'albanel',
#  'grimari',
#  'mangochi',
#  'melun',
#  'wittingen',
#  'port blair',
#  'cururupu',
#  'hithadhoo',
#  'luderitz',
#  'general pico',
#  'hasaki',
#  'kwinana',
#  'lumphat',
#  'longhua',
#  'lagunas',
#  'saryshagan',
#  'tanta',
#  'jinchang',
#  'seoul',
#  'mahebourg',
#  'busselton',
#  'nichinan',
#  'barentsburg',
#  'bargal',
#  'mount isa',
#  'pontefract',
#  'kavieng',
#  'sindou',
#  'inhambane',
#  'concordia',
#  'ponta do sol',
#  'mar del plata',
#  'atyashevo',
#  'coruripe',
#  'sisimiut',
#  'tigre',
#  'zemio',
#  'jiazi',
#  'trelew',
#  'nemuro',
#  'karasburg',
#  'kasempa',
#  'talakan',
#  'hamilton',
#  'tabiauea',
#  'dno',
#  'sombrio',
#  'saint-vallier',
#  'banswara',
#  'santa rosa',
#  'port elizabeth',
#  'kamaishi',
#  'maceio',
#  'wajima',
#  'shihezi',
#  'ambon',
#  'mabay',
#  'guekedou',
#  'ocho rios',
#  'tapiramuta',
#  'sembe',
#  'gaborone',
#  'te anau',
#  'teguldet',
#  'broken hill',
#  'bluff',
#  'nogliki',
#  'saint-philippe',
#  'tawnat',
#  'blanquefort',
#  'tura',
#  'ponta delgada',
#  'sao joao da barra',
#  'soyo',
#  'manutuke',
#  'dumai',
#  'mandalgovi',
#  'fort-shevchenko',
#  'bengkulu',
#  'fomboni',
#  'zyryanka',
#  'sept-iles',
#  'bonfim',
#  'liverpool',
#  'auki',
#  'koumac',
#  'punta arenas',
#  'xiaoyi',
#  'ust-kan',
#  'alekseyevka',
#  'hovd',
#  'rawson',
#  'grand gaube',
#  'leh',
#  'snezhnogorsk',
#  'muzaffarabad',
#  'ilebo',
#  'soma',
#  'chokurdakh',
#  'saint anthony',
#  'fevralsk',
#  'ichhawar',
#  'takoradi',
#  'krasnoselkup',
#  'nguiu',
#  'colares',
#  'saskylakh',
#  'karoi',
#  'oranjestad',
#  'namibe',
#  'carnarvon',
#  'molina',
#  'westport',
#  'ihosy',
#  'neuquen',
#  'marsabit',
#  'ust-kut',
#  'alotau',
#  'cheremukhovo',
#  'russkiy aktash',
#  'miri',
#  'mrirt',
#  'tual',
#  'mlonggo',
#  'coihaique',
#  'kiama',
#  'tondano',
#  'carbonia',
#  'eyl',
#  'dolbeau',
#  'calabozo',
#  'baripada',
#  'dhidhdhoo',
#  'onega',
#  'meulaboh',
#  'hoa binh',
#  'rio grande',
#  'chake chake',
#  'karauzyak',
#  'nikolskoye',
#  'sorong',
#  'vanimo',
#  'panukulan',
#  'dniprorudne',
#  'tornio',
#  'codajas',
#  'kusye-aleksandrovskiy',
#  'srednekolymsk',
#  'port-cartier',
#  'wenzhou',
#  'maloshuyka',
#  'hambantota',
#  'kalabo',
#  'kurovskoy',
#  'dalvik',
#  'lodja',
#  'mana',
#  'emerald',
#  'tarko-sale',
#  'skala',
#  'hat yai',
#  'canico',
#  'turukhansk',
#  'kristiinankaupunki',
#  'werder',
#  'cukai',
#  'vagur',
#  'iranshahr',
#  'togur',
#  'thaton',
#  'petropavlovsk-kamchatskiy',
#  'praia da vitoria',
#  'kieta',
#  'quatre cocos',
#  'rungata',
#  'longyearbyen',
#  'myaundzha',
#  'aksu',
#  'ust-maya',
#  'vila velha',
#  'joao pinheiro',
#  'acin',
#  'meyungs',
#  'birjand',
#  'albany',
#  'gazimurskiy zavod',
#  'maningrida',
#  'yuty',
#  'riyadh',
#  'bonavista',
#  'klaipeda',
#  'pevek',
#  'sayyan',
#  'santa cruz cabralia',
#  'chhagalnaiya',
#  'cabatuan',
#  'comodoro rivadavia',
#  'digha',
#  'pemangkat',
#  'ambilobe',
#  'malatya',
#  'santiago del estero',
#  'erdemli',
#  'los llanos de aridane',
#  'ondjiva',
#  'vadlapudi',
#  'lusaka',
#  'roebourne',
#  'ballina',
#  'svetlaya',
#  'maarianhamina',
#  'ola',
#  'karakendzha',
#  'marzuq',
#  'san alberto',
#  'inta',
#  'fiumicino',
#  'libertador general san martin',
#  'mogadishu',
#  'bambanglipuro',
#  'ngunguru',
#  'klaksvik',
#  'berlevag',
#  'nelidovo',
#  'linhares',
#  'beloha',
#  'majene',
#  'pundaguitan',
#  'bubaque',
#  'askiz',
#  'solsvik',
#  'tevriz',
#  'san ramon',
#  'aguimes',
#  'syracuse',
#  'buala',
#  'uvira',
#  'amuntai',
#  'vetlanda',
#  'carballo',
#  'moron',
#  'det udom',
#  'aden',
#  'vylok',
#  'fosser',
#  'constantine',
#  'indiaroba',
#  'beroroha',
#  'zabol',
#  'ushuaia',
#  'upernavik',
#  'lithgow',
#  'banmo',
#  'novo aripuana',
#  'teguise',
#  'kudahuvadhoo',
#  'finschhafen',
#  'tarsus',
#  'leningradskiy',
#  'butaritari',
#  'siguiri',
#  'taolanaro',
#  'grand river south east',
#  'nchelenge',
#  'codrington',
#  'dekoa',
#  'touros',
#  'vanavara',
#  'bolungarvik',
#  'new norfolk',
#  'redditch',
#  'turkmenabat',
#  'nago',
#  'verkhoyansk',
#  'roald',
#  'adrar',
#  'tsihombe',
#  'gravdal',
#  'saldanha',
#  'bathsheba',
#  'balclutha',
#  'vakhrushev',
#  'parabel',
#  'tommot',
#  'yako',
#  'coquimbo',
#  'namie',
#  'san ignacio',
#  'east london',
#  'cayenne',
#  'kuruman',
#  'santa luzia',
#  'victoria',
#  'guantanamo',
#  'pyaozerskiy',
#  'tromso',
#  'bairiki',
#  'ouanaminthe',
#  'saint george',
#  'bayir',
#  'port hope',
#  'isangel',
#  'iracoubo',
#  'gwadar',
#  'zwedru',
#  'nelson bay',
#  'belyy yar',
#  'dzhusaly',
#  'okato',
#  'upington',
#  'ilave',
#  'kaitangata',
#  'san joaquin',
#  'manicore',
#  'araouane',
#  'tete',
#  'bereda',
#  'iqaluit',
#  'bressanone',
#  'rennes',
#  'nabire',
#  'chuy',
#  'utiroa',
#  'chern',
#  'miracema do tocantins',
#  'mount gambier',
#  'saint-germain-de-grantham',
#  'belaya gora',
#  'kovdor',
#  'mishan',
#  'kulob',
#  'brae',
#  'solovetskiy',
#  'palabuhanratu',
#  'seit',
#  'marawi',
#  'atambua',
#  'noumea',
#  'poum',
#  'bridlington',
#  'bochnia',
#  'mosquera',
#  'cap malheureux',
#  'sorvag',
#  'usinsk',
#  'wakefield',
#  'san antero',
#  'hermanus',
#  'nanortalik',
#  'vestmanna',
#  'dingle',
#  'lakatoro',
#  'dolores',
#  'xining',
#  'wagar',
#  'fort wellington',
#  'aflu',
#  'port-gentil',
#  'sao gabriel da cachoeira',
#  'grindavik',
#  'komsomolskiy',
#  'voh',
#  'kalmunai',
#  'manzhouli',
#  'izhmorskiy',
#  'vila franca do campo',
#  'na wa',
#  'san vicente',
#  'shubarkuduk',
#  'airai',
#  'shimoda',
#  'mosetse',
#  'jizan',
#  'maltahohe',
#  'katsuura',
#  'kaseda',
#  'mwinilunga',
#  'kamp-lintfort',
#  'nuuk',
#  'chernyshevskiy',
#  'talcher',
#  'impfondo',
#  'santa maria',
#  'biltine',
#  'khonuu',
#  'port keats',
#  'kohima',
#  'sredneuralsk',
#  'likasi',
#  'skelleftea',
#  'alekseyevsk',
#  'yevsino',
#  'kholmogory']

# %%
# API url
url = f'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}'
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for city in cities:
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    if record_count > 60:
        record_count = 1
        set_count += 1
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jomalig
# City not found. Skipping...
# Processing Record 2 of Set 1 | kabinda
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | sassandra
# Processing Record 5 of Set 1 | navalmoral de la mata
# Processing Record 6 of Set 1 | kachiry
# Processing Record 7 of Set 1 | kruisfontein
# Processing Record 8 of Set 1 | nouakchott
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | batsfjord
# Processing Record 11 of Set 1 | vao
# Processing Record 12 of Set 1 | ipubi
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | sobolevo
# Processing Record 15 of Set 1 | muzaffargarh
# Processing Record 16 of Set 1 | podyuga
# Processing Record 17 of Set 1 | lethem
# Processing Record 18 of Set 1 | bonthe
# Processing Record 19 of Set 1 | jaciara
# Processing Record 20 of Set 1 | praya
# Processing Record 21 of Set 1 | ardakan
# Processing Record 22 of Set 1 | luyang
# Processing Record 23 of Set 1 | nsawam
# Processing Record 24 of Set 1 | evensk
# Processing Record 25 of Set 1 | veraval
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | oussouye
# Processing Record 28 of Set 1 | khasan
# Processing Record 29 of Set 1 | rio gallegos
# Processing Record 30 of Set 1 | potiskum
# Processing Record 31 of Set 1 | stornoway
# Processing Record 32 of Set 1 | pangnirtung
# Processing Record 33 of Set 1 | ilesha
# Processing Record 34 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 35 of Set 1 | ulundi
# Processing Record 36 of Set 1 | hirara
# Processing Record 37 of Set 1 | hvammstangi
# City not found. Skipping...
# Processing Record 38 of Set 1 | neryungri
# Processing Record 39 of Set 1 | thoen
# Processing Record 40 of Set 1 | isparta
# Processing Record 41 of Set 1 | pozo colorado
# Processing Record 42 of Set 1 | qorveh
# Processing Record 43 of Set 1 | lata
# Processing Record 44 of Set 1 | adre
# Processing Record 45 of Set 1 | tarancon
# Processing Record 46 of Set 1 | turbat
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | baruun-urt
# Processing Record 49 of Set 1 | bolshoy uluy
# City not found. Skipping...
# Processing Record 50 of Set 1 | ibra
# Processing Record 51 of Set 1 | gayeri
# Processing Record 52 of Set 1 | beringovskiy
# Processing Record 53 of Set 1 | tasiilaq
# Processing Record 54 of Set 1 | baffa
# Processing Record 55 of Set 1 | yabelo
# Processing Record 56 of Set 1 | behshahr
# Processing Record 57 of Set 1 | rocha
# Processing Record 58 of Set 1 | anzio
# Processing Record 59 of Set 1 | kutum
# Processing Record 60 of Set 1 | roma
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | manakara
# Processing Record 3 of Set 2 | noshiro
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | road town
# Processing Record 6 of Set 2 | burgos
# Processing Record 7 of Set 2 | saint-pierre
# Processing Record 8 of Set 2 | ambulu
# Processing Record 9 of Set 2 | olafsvik
# Processing Record 10 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 2 | tilichiki
# Processing Record 12 of Set 2 | kathu
# Processing Record 13 of Set 2 | rajula
# Processing Record 14 of Set 2 | armilla
# Processing Record 15 of Set 2 | huangnihe
# Processing Record 16 of Set 2 | thurso
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | murgab
# Processing Record 19 of Set 2 | bujaru
# Processing Record 20 of Set 2 | parakai
# Processing Record 21 of Set 2 | senneterre
# Processing Record 22 of Set 2 | gap
# Processing Record 23 of Set 2 | bennington
# Processing Record 24 of Set 2 | karwar
# Processing Record 25 of Set 2 | kiunga
# Processing Record 26 of Set 2 | galesong
# Processing Record 27 of Set 2 | tazovskiy
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | gagarin
# Processing Record 30 of Set 2 | norrtalje
# Processing Record 31 of Set 2 | keuruu
# Processing Record 32 of Set 2 | kibala
# Processing Record 33 of Set 2 | katobu
# Processing Record 34 of Set 2 | virginia beach
# Processing Record 35 of Set 2 | yerbogachen
# Processing Record 36 of Set 2 | perth
# Processing Record 37 of Set 2 | bid
# City not found. Skipping...
# Processing Record 38 of Set 2 | hofn
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | remedios
# Processing Record 41 of Set 2 | anadyr
# Processing Record 42 of Set 2 | nizhniy tsasuchey
# Processing Record 43 of Set 2 | puteyets
# Processing Record 44 of Set 2 | muroto
# Processing Record 45 of Set 2 | walvis bay
# Processing Record 46 of Set 2 | unai
# Processing Record 47 of Set 2 | poya
# Processing Record 48 of Set 2 | the valley
# Processing Record 49 of Set 2 | morondava
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 51 of Set 2 | qaqortoq
# Processing Record 52 of Set 2 | clyde river
# Processing Record 53 of Set 2 | khatanga
# Processing Record 54 of Set 2 | porto santo
# Processing Record 55 of Set 2 | katherine
# Processing Record 56 of Set 2 | padang
# Processing Record 57 of Set 2 | taoudenni
# Processing Record 58 of Set 2 | umm lajj
# Processing Record 59 of Set 2 | vostok
# Processing Record 60 of Set 2 | itarema
# Processing Record 1 of Set 3 | husavik
# Processing Record 2 of Set 3 | kholodnyy
# Processing Record 3 of Set 3 | crixas
# Processing Record 4 of Set 3 | odweyne
# Processing Record 5 of Set 3 | anloga
# Processing Record 6 of Set 3 | vila do maio
# Processing Record 7 of Set 3 | kuytun
# Processing Record 8 of Set 3 | paamiut
# Processing Record 9 of Set 3 | birao
# Processing Record 10 of Set 3 | lagoa
# Processing Record 11 of Set 3 | barra do garcas
# Processing Record 12 of Set 3 | khandyga
# Processing Record 13 of Set 3 | mayumba
# Processing Record 14 of Set 3 | linxia
# Processing Record 15 of Set 3 | puerto maldonado
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | lusambo
# Processing Record 18 of Set 3 | tuy hoa
# Processing Record 19 of Set 3 | lourdes
# Processing Record 20 of Set 3 | luanda
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | namatanai
# Processing Record 23 of Set 3 | boden
# Processing Record 24 of Set 3 | balatonboglar
# Processing Record 25 of Set 3 | zhaotong
# Processing Record 26 of Set 3 | richards bay
# Processing Record 27 of Set 3 | dera ghazi khan
# Processing Record 28 of Set 3 | gigmoto
# Processing Record 29 of Set 3 | sangar
# Processing Record 30 of Set 3 | rovaniemi
# Processing Record 31 of Set 3 | dudinka
# Processing Record 32 of Set 3 | labuan
# Processing Record 33 of Set 3 | polovinnoye
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | shepsi
# Processing Record 36 of Set 3 | poso
# Processing Record 37 of Set 3 | krasnoufimsk
# Processing Record 38 of Set 3 | cockburn town
# Processing Record 39 of Set 3 | korla
# Processing Record 40 of Set 3 | mtsensk
# Processing Record 41 of Set 3 | chapais
# Processing Record 42 of Set 3 | arroyo
# Processing Record 43 of Set 3 | nohar
# Processing Record 44 of Set 3 | omboue
# Processing Record 45 of Set 3 | sibolga
# Processing Record 46 of Set 3 | keetmanshoop
# Processing Record 47 of Set 3 | toropets
# Processing Record 48 of Set 3 | novorozhdestvenskaya
# Processing Record 49 of Set 3 | jedrzejow
# Processing Record 50 of Set 3 | mareeba
# Processing Record 51 of Set 3 | preobrazheniye
# Processing Record 52 of Set 3 | caravelas
# Processing Record 53 of Set 3 | biak
# Processing Record 54 of Set 3 | torbay
# Processing Record 55 of Set 3 | wazzan
# City not found. Skipping...
# Processing Record 56 of Set 3 | port hedland
# Processing Record 57 of Set 3 | nikolsk
# Processing Record 58 of Set 3 | laguna
# Processing Record 59 of Set 3 | mangrol
# Processing Record 60 of Set 3 | vucje
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | gao
# Processing Record 3 of Set 4 | luganville
# Processing Record 4 of Set 4 | oranjemund
# Processing Record 5 of Set 4 | saint-augustin
# Processing Record 6 of Set 4 | puerto ayacucho
# Processing Record 7 of Set 4 | siena
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 10 of Set 4 | byron bay
# Processing Record 11 of Set 4 | sola
# Processing Record 12 of Set 4 | saquena
# Processing Record 13 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 4 | salinopolis
# Processing Record 16 of Set 4 | nepalganj
# City not found. Skipping...
# Processing Record 17 of Set 4 | shakiso
# Processing Record 18 of Set 4 | viedma
# Processing Record 19 of Set 4 | lagos
# Processing Record 20 of Set 4 | dekar
# Processing Record 21 of Set 4 | ahipara
# Processing Record 22 of Set 4 | senanga
# Processing Record 23 of Set 4 | negrar
# Processing Record 24 of Set 4 | nouadhibou
# Processing Record 25 of Set 4 | doha
# Processing Record 26 of Set 4 | scarborough
# Processing Record 27 of Set 4 | souillac
# Processing Record 28 of Set 4 | svetlogorsk
# Processing Record 29 of Set 4 | kavaratti
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | maniitsoq
# Processing Record 32 of Set 4 | gat
# Processing Record 33 of Set 4 | thano bula khan
# City not found. Skipping...
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | jaque
# Processing Record 36 of Set 4 | ampanihy
# Processing Record 37 of Set 4 | nantucket
# Processing Record 38 of Set 4 | zhangye
# Processing Record 39 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 4 | jian
# Processing Record 41 of Set 4 | itacarambi
# Processing Record 42 of Set 4 | banda aceh
# Processing Record 43 of Set 4 | altay
# Processing Record 44 of Set 4 | serebryansk
# Processing Record 45 of Set 4 | killybegs
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | salalah
# Processing Record 48 of Set 4 | ust-barguzin
# Processing Record 49 of Set 4 | uglovskoye
# Processing Record 50 of Set 4 | kapit
# Processing Record 51 of Set 4 | asau
# Processing Record 52 of Set 4 | san lawrenz
# Processing Record 53 of Set 4 | quillota
# Processing Record 54 of Set 4 | megion
# Processing Record 55 of Set 4 | buraydah
# Processing Record 56 of Set 4 | jamestown
# Processing Record 57 of Set 4 | hvide sande
# Processing Record 58 of Set 4 | marsa matruh
# Processing Record 59 of Set 4 | erzin
# Processing Record 60 of Set 4 | mehamn
# Processing Record 1 of Set 5 | narsaq
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | naze
# Processing Record 4 of Set 5 | mananjary
# Processing Record 5 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 5 | la rioja
# Processing Record 7 of Set 5 | bulaevo
# Processing Record 8 of Set 5 | mezen
# Processing Record 9 of Set 5 | lakes entrance
# Processing Record 10 of Set 5 | leua
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | zastron
# Processing Record 13 of Set 5 | surt
# Processing Record 14 of Set 5 | carutapera
# Processing Record 15 of Set 5 | bam
# Processing Record 16 of Set 5 | pando
# Processing Record 17 of Set 5 | mildura
# Processing Record 18 of Set 5 | mercedes
# Processing Record 19 of Set 5 | afua
# Processing Record 20 of Set 5 | torres
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | soe
# Processing Record 23 of Set 5 | cravo norte
# Processing Record 24 of Set 5 | chifeng
# Processing Record 25 of Set 5 | jumla
# Processing Record 26 of Set 5 | robertsport
# Processing Record 27 of Set 5 | vardo
# Processing Record 28 of Set 5 | tamworth
# Processing Record 29 of Set 5 | piopio
# Processing Record 30 of Set 5 | maraa
# Processing Record 31 of Set 5 | polunochnoye
# Processing Record 32 of Set 5 | rudnaya pristan
# Processing Record 33 of Set 5 | northam
# Processing Record 34 of Set 5 | kysyl-syr
# Processing Record 35 of Set 5 | tacoronte
# Processing Record 36 of Set 5 | mnogovershinnyy
# Processing Record 37 of Set 5 | diu
# Processing Record 38 of Set 5 | bosaso
# Processing Record 39 of Set 5 | bagdarin
# Processing Record 40 of Set 5 | kloulklubed
# Processing Record 41 of Set 5 | dyadkovskaya
# City not found. Skipping...
# Processing Record 42 of Set 5 | sencha
# Processing Record 43 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 5 | le port
# Processing Record 45 of Set 5 | sao filipe
# Processing Record 46 of Set 5 | berberati
# Processing Record 47 of Set 5 | bentiu
# Processing Record 48 of Set 5 | nokaneng
# Processing Record 49 of Set 5 | zaysan
# Processing Record 50 of Set 5 | arman
# Processing Record 51 of Set 5 | weligama
# Processing Record 52 of Set 5 | visby
# Processing Record 53 of Set 5 | lodeynoye pole
# Processing Record 54 of Set 5 | konevo
# Processing Record 55 of Set 5 | joshimath
# Processing Record 56 of Set 5 | shubarshi
# Processing Record 57 of Set 5 | ribeira grande
# Processing Record 58 of Set 5 | kijang
# Processing Record 59 of Set 5 | illapel
# Processing Record 60 of Set 5 | dubovka
# Processing Record 1 of Set 6 | skibbereen
# Processing Record 2 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 6 | hurghada
# Processing Record 4 of Set 6 | kamenka
# Processing Record 5 of Set 6 | stromness
# Processing Record 6 of Set 6 | umtata
# Processing Record 7 of Set 6 | general roca
# Processing Record 8 of Set 6 | podgornoye
# Processing Record 9 of Set 6 | halifax
# Processing Record 10 of Set 6 | sao jose da coroa grande
# Processing Record 11 of Set 6 | kpandae
# Processing Record 12 of Set 6 | panguna
# Processing Record 13 of Set 6 | goderich
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | gurupa
# Processing Record 16 of Set 6 | hinckley
# Processing Record 17 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 6 | kaeo
# Processing Record 19 of Set 6 | shahr-e kord
# Processing Record 20 of Set 6 | puerto carreno
# Processing Record 21 of Set 6 | baykit
# Processing Record 22 of Set 6 | cerrito
# Processing Record 23 of Set 6 | port augusta
# Processing Record 24 of Set 6 | oytal
# Processing Record 25 of Set 6 | kansanshi
# Processing Record 26 of Set 6 | hue
# Processing Record 27 of Set 6 | bousso
# Processing Record 28 of Set 6 | kortkeros
# Processing Record 29 of Set 6 | menongue
# Processing Record 30 of Set 6 | harper
# Processing Record 31 of Set 6 | karratha
# Processing Record 32 of Set 6 | hobyo
# Processing Record 33 of Set 6 | calvinia
# Processing Record 34 of Set 6 | ko samui
# Processing Record 35 of Set 6 | santa cruz
# Processing Record 36 of Set 6 | vila
# Processing Record 37 of Set 6 | talnakh
# Processing Record 38 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 6 | yuzhno-kurilsk
# Processing Record 42 of Set 6 | belozerskoye
# Processing Record 43 of Set 6 | mastic beach
# Processing Record 44 of Set 6 | shingu
# Processing Record 45 of Set 6 | porangatu
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | zhigansk
# Processing Record 48 of Set 6 | kribi
# Processing Record 49 of Set 6 | baoning
# Processing Record 50 of Set 6 | tiznit
# Processing Record 51 of Set 6 | samarai
# Processing Record 52 of Set 6 | chingola
# Processing Record 53 of Set 6 | ust-koksa
# Processing Record 54 of Set 6 | marovoay
# Processing Record 55 of Set 6 | bandarbeyla
# Processing Record 56 of Set 6 | tolaga bay
# Processing Record 57 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 58 of Set 6 | mackay
# Processing Record 59 of Set 6 | vitoria
# Processing Record 60 of Set 6 | vigrestad
# Processing Record 1 of Set 7 | amapa
# Processing Record 2 of Set 7 | balaguer
# Processing Record 3 of Set 7 | lodwar
# Processing Record 4 of Set 7 | ybbs
# City not found. Skipping...
# Processing Record 5 of Set 7 | sur
# Processing Record 6 of Set 7 | sokoni
# Processing Record 7 of Set 7 | bauchi
# Processing Record 8 of Set 7 | port macquarie
# Processing Record 9 of Set 7 | howard springs
# Processing Record 10 of Set 7 | mecca
# Processing Record 11 of Set 7 | merauke
# Processing Record 12 of Set 7 | purpe
# Processing Record 13 of Set 7 | barentu
# Processing Record 14 of Set 7 | gornoye loo
# Processing Record 15 of Set 7 | ramhormoz
# Processing Record 16 of Set 7 | port alfred
# Processing Record 17 of Set 7 | ayr
# Processing Record 18 of Set 7 | lumut
# Processing Record 19 of Set 7 | garchitorena
# Processing Record 20 of Set 7 | kangaatsiaq
# Processing Record 21 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 22 of Set 7 | machiques
# Processing Record 23 of Set 7 | maragogi
# Processing Record 24 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 7 | verkhoshizhemye
# Processing Record 26 of Set 7 | yulara
# Processing Record 27 of Set 7 | jalu
# Processing Record 28 of Set 7 | havre-saint-pierre
# Processing Record 29 of Set 7 | gouyave
# Processing Record 30 of Set 7 | pantai remis
# Processing Record 31 of Set 7 | catamarca
# Processing Record 32 of Set 7 | ayios matthaios
# City not found. Skipping...
# Processing Record 33 of Set 7 | albanel
# Processing Record 34 of Set 7 | grimari
# City not found. Skipping...
# Processing Record 35 of Set 7 | mangochi
# Processing Record 36 of Set 7 | melun
# Processing Record 37 of Set 7 | wittingen
# Processing Record 38 of Set 7 | port blair
# Processing Record 39 of Set 7 | cururupu
# Processing Record 40 of Set 7 | hithadhoo
# Processing Record 41 of Set 7 | luderitz
# Processing Record 42 of Set 7 | general pico
# Processing Record 43 of Set 7 | hasaki
# Processing Record 44 of Set 7 | kwinana
# Processing Record 45 of Set 7 | lumphat
# Processing Record 46 of Set 7 | longhua
# Processing Record 47 of Set 7 | lagunas
# Processing Record 48 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 49 of Set 7 | tanta
# Processing Record 50 of Set 7 | jinchang
# Processing Record 51 of Set 7 | seoul
# Processing Record 52 of Set 7 | mahebourg
# Processing Record 53 of Set 7 | busselton
# Processing Record 54 of Set 7 | nichinan
# Processing Record 55 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 56 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 57 of Set 7 | mount isa
# Processing Record 58 of Set 7 | pontefract
# Processing Record 59 of Set 7 | kavieng
# Processing Record 60 of Set 7 | sindou
# Processing Record 1 of Set 8 | inhambane
# Processing Record 2 of Set 8 | concordia
# Processing Record 3 of Set 8 | ponta do sol
# Processing Record 4 of Set 8 | mar del plata
# Processing Record 5 of Set 8 | atyashevo
# Processing Record 6 of Set 8 | coruripe
# Processing Record 7 of Set 8 | sisimiut
# Processing Record 8 of Set 8 | tigre
# Processing Record 9 of Set 8 | zemio
# Processing Record 10 of Set 8 | jiazi
# Processing Record 11 of Set 8 | trelew
# Processing Record 12 of Set 8 | nemuro
# Processing Record 13 of Set 8 | karasburg
# Processing Record 14 of Set 8 | kasempa
# Processing Record 15 of Set 8 | talakan
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 8 | dno
# Processing Record 19 of Set 8 | sombrio
# Processing Record 20 of Set 8 | saint-vallier
# Processing Record 21 of Set 8 | banswara
# Processing Record 22 of Set 8 | santa rosa
# Processing Record 23 of Set 8 | port elizabeth
# Processing Record 24 of Set 8 | kamaishi
# Processing Record 25 of Set 8 | maceio
# Processing Record 26 of Set 8 | wajima
# Processing Record 27 of Set 8 | shihezi
# Processing Record 28 of Set 8 | ambon
# Processing Record 29 of Set 8 | mabay
# Processing Record 30 of Set 8 | guekedou
# City not found. Skipping...
# Processing Record 31 of Set 8 | ocho rios
# Processing Record 32 of Set 8 | tapiramuta
# Processing Record 33 of Set 8 | sembe
# Processing Record 34 of Set 8 | gaborone
# Processing Record 35 of Set 8 | te anau
# Processing Record 36 of Set 8 | teguldet
# Processing Record 37 of Set 8 | broken hill
# Processing Record 38 of Set 8 | bluff
# Processing Record 39 of Set 8 | nogliki
# Processing Record 40 of Set 8 | saint-philippe
# Processing Record 41 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 42 of Set 8 | blanquefort
# Processing Record 43 of Set 8 | tura
# Processing Record 44 of Set 8 | ponta delgada
# Processing Record 45 of Set 8 | sao joao da barra
# Processing Record 46 of Set 8 | soyo
# Processing Record 47 of Set 8 | manutuke
# Processing Record 48 of Set 8 | dumai
# Processing Record 49 of Set 8 | mandalgovi
# Processing Record 50 of Set 8 | fort-shevchenko
# Processing Record 51 of Set 8 | bengkulu
# Processing Record 52 of Set 8 | fomboni
# Processing Record 53 of Set 8 | zyryanka
# Processing Record 54 of Set 8 | sept-iles
# Processing Record 55 of Set 8 | bonfim
# Processing Record 56 of Set 8 | liverpool
# Processing Record 57 of Set 8 | auki
# Processing Record 58 of Set 8 | koumac
# Processing Record 59 of Set 8 | punta arenas
# Processing Record 60 of Set 8 | xiaoyi
# Processing Record 1 of Set 9 | ust-kan
# Processing Record 2 of Set 9 | alekseyevka
# Processing Record 3 of Set 9 | hovd
# Processing Record 4 of Set 9 | rawson
# Processing Record 5 of Set 9 | grand gaube
# Processing Record 6 of Set 9 | leh
# Processing Record 7 of Set 9 | snezhnogorsk
# Processing Record 8 of Set 9 | muzaffarabad
# Processing Record 9 of Set 9 | ilebo
# Processing Record 10 of Set 9 | soma
# Processing Record 11 of Set 9 | chokurdakh
# Processing Record 12 of Set 9 | saint anthony
# Processing Record 13 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 9 | ichhawar
# Processing Record 15 of Set 9 | takoradi
# Processing Record 16 of Set 9 | krasnoselkup
# Processing Record 17 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 9 | colares
# Processing Record 19 of Set 9 | saskylakh
# Processing Record 20 of Set 9 | karoi
# Processing Record 21 of Set 9 | oranjestad
# Processing Record 22 of Set 9 | namibe
# Processing Record 23 of Set 9 | carnarvon
# Processing Record 24 of Set 9 | molina
# Processing Record 25 of Set 9 | westport
# Processing Record 26 of Set 9 | ihosy
# Processing Record 27 of Set 9 | neuquen
# Processing Record 28 of Set 9 | marsabit
# Processing Record 29 of Set 9 | ust-kut
# Processing Record 30 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 9 | cheremukhovo
# Processing Record 32 of Set 9 | russkiy aktash
# Processing Record 33 of Set 9 | miri
# Processing Record 34 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 9 | tual
# Processing Record 36 of Set 9 | mlonggo
# Processing Record 37 of Set 9 | coihaique
# Processing Record 38 of Set 9 | kiama
# Processing Record 39 of Set 9 | tondano
# Processing Record 40 of Set 9 | carbonia
# Processing Record 41 of Set 9 | eyl
# Processing Record 42 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 43 of Set 9 | calabozo
# Processing Record 44 of Set 9 | baripada
# Processing Record 45 of Set 9 | dhidhdhoo
# Processing Record 46 of Set 9 | onega
# Processing Record 47 of Set 9 | meulaboh
# Processing Record 48 of Set 9 | hoa binh
# Processing Record 49 of Set 9 | rio grande
# Processing Record 50 of Set 9 | chake chake
# Processing Record 51 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 52 of Set 9 | nikolskoye
# Processing Record 53 of Set 9 | sorong
# Processing Record 54 of Set 9 | vanimo
# Processing Record 55 of Set 9 | panukulan
# Processing Record 56 of Set 9 | dniprorudne
# Processing Record 57 of Set 9 | tornio
# Processing Record 58 of Set 9 | codajas
# Processing Record 59 of Set 9 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 60 of Set 9 | srednekolymsk
# Processing Record 1 of Set 10 | port-cartier
# Processing Record 2 of Set 10 | wenzhou
# Processing Record 3 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | kalabo
# Processing Record 6 of Set 10 | kurovskoy
# City not found. Skipping...
# Processing Record 7 of Set 10 | dalvik
# Processing Record 8 of Set 10 | lodja
# Processing Record 9 of Set 10 | mana
# Processing Record 10 of Set 10 | emerald
# Processing Record 11 of Set 10 | tarko-sale
# Processing Record 12 of Set 10 | skala
# Processing Record 13 of Set 10 | hat yai
# Processing Record 14 of Set 10 | canico
# Processing Record 15 of Set 10 | turukhansk
# Processing Record 16 of Set 10 | kristiinankaupunki
# Processing Record 17 of Set 10 | werder
# Processing Record 18 of Set 10 | cukai
# Processing Record 19 of Set 10 | vagur
# Processing Record 20 of Set 10 | iranshahr
# Processing Record 21 of Set 10 | togur
# Processing Record 22 of Set 10 | thaton
# Processing Record 23 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 10 | praia da vitoria
# Processing Record 25 of Set 10 | kieta
# Processing Record 26 of Set 10 | quatre cocos
# Processing Record 27 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 10 | longyearbyen
# Processing Record 29 of Set 10 | myaundzha
# Processing Record 30 of Set 10 | aksu
# Processing Record 31 of Set 10 | ust-maya
# Processing Record 32 of Set 10 | vila velha
# Processing Record 33 of Set 10 | joao pinheiro
# Processing Record 34 of Set 10 | acin
# City not found. Skipping...
# Processing Record 35 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 10 | birjand
# Processing Record 37 of Set 10 | albany
# Processing Record 38 of Set 10 | gazimurskiy zavod
# Processing Record 39 of Set 10 | maningrida
# Processing Record 40 of Set 10 | yuty
# Processing Record 41 of Set 10 | riyadh
# Processing Record 42 of Set 10 | bonavista
# Processing Record 43 of Set 10 | klaipeda
# Processing Record 44 of Set 10 | pevek
# Processing Record 45 of Set 10 | sayyan
# Processing Record 46 of Set 10 | santa cruz cabralia
# Processing Record 47 of Set 10 | chhagalnaiya
# Processing Record 48 of Set 10 | cabatuan
# Processing Record 49 of Set 10 | comodoro rivadavia
# Processing Record 50 of Set 10 | digha
# Processing Record 51 of Set 10 | pemangkat
# Processing Record 52 of Set 10 | ambilobe
# Processing Record 53 of Set 10 | malatya
# Processing Record 54 of Set 10 | santiago del estero
# Processing Record 55 of Set 10 | erdemli
# Processing Record 56 of Set 10 | los llanos de aridane
# Processing Record 57 of Set 10 | ondjiva
# Processing Record 58 of Set 10 | vadlapudi
# Processing Record 59 of Set 10 | lusaka
# Processing Record 60 of Set 10 | roebourne
# Processing Record 1 of Set 11 | ballina
# Processing Record 2 of Set 11 | svetlaya
# Processing Record 3 of Set 11 | maarianhamina
# Processing Record 4 of Set 11 | ola
# Processing Record 5 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 6 of Set 11 | marzuq
# Processing Record 7 of Set 11 | san alberto
# Processing Record 8 of Set 11 | inta
# Processing Record 9 of Set 11 | fiumicino
# Processing Record 10 of Set 11 | libertador general san martin
# Processing Record 11 of Set 11 | mogadishu
# Processing Record 12 of Set 11 | bambanglipuro
# Processing Record 13 of Set 11 | ngunguru
# Processing Record 14 of Set 11 | klaksvik
# Processing Record 15 of Set 11 | berlevag
# Processing Record 16 of Set 11 | nelidovo
# Processing Record 17 of Set 11 | linhares
# Processing Record 18 of Set 11 | beloha
# Processing Record 19 of Set 11 | majene
# Processing Record 20 of Set 11 | pundaguitan
# Processing Record 21 of Set 11 | bubaque
# Processing Record 22 of Set 11 | askiz
# Processing Record 23 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 24 of Set 11 | tevriz
# Processing Record 25 of Set 11 | san ramon
# Processing Record 26 of Set 11 | aguimes
# Processing Record 27 of Set 11 | syracuse
# Processing Record 28 of Set 11 | buala
# Processing Record 29 of Set 11 | uvira
# Processing Record 30 of Set 11 | amuntai
# Processing Record 31 of Set 11 | vetlanda
# Processing Record 32 of Set 11 | carballo
# Processing Record 33 of Set 11 | moron
# Processing Record 34 of Set 11 | det udom
# Processing Record 35 of Set 11 | aden
# Processing Record 36 of Set 11 | vylok
# Processing Record 37 of Set 11 | fosser
# City not found. Skipping...
# Processing Record 38 of Set 11 | constantine
# Processing Record 39 of Set 11 | indiaroba
# Processing Record 40 of Set 11 | beroroha
# Processing Record 41 of Set 11 | zabol
# Processing Record 42 of Set 11 | ushuaia
# Processing Record 43 of Set 11 | upernavik
# Processing Record 44 of Set 11 | lithgow
# Processing Record 45 of Set 11 | banmo
# City not found. Skipping...
# Processing Record 46 of Set 11 | novo aripuana
# Processing Record 47 of Set 11 | teguise
# Processing Record 48 of Set 11 | kudahuvadhoo
# Processing Record 49 of Set 11 | finschhafen
# Processing Record 50 of Set 11 | tarsus
# Processing Record 51 of Set 11 | leningradskiy
# Processing Record 52 of Set 11 | butaritari
# Processing Record 53 of Set 11 | siguiri
# Processing Record 54 of Set 11 | taolanaro
# City not found. Skipping...
# Processing Record 55 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 56 of Set 11 | nchelenge
# Processing Record 57 of Set 11 | codrington
# Processing Record 58 of Set 11 | dekoa
# City not found. Skipping...
# Processing Record 59 of Set 11 | touros
# Processing Record 60 of Set 11 | vanavara
# Processing Record 1 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 12 | new norfolk
# Processing Record 3 of Set 12 | redditch
# Processing Record 4 of Set 12 | turkmenabat
# Processing Record 5 of Set 12 | nago
# Processing Record 6 of Set 12 | verkhoyansk
# Processing Record 7 of Set 12 | roald
# Processing Record 8 of Set 12 | adrar
# Processing Record 9 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 12 | gravdal
# Processing Record 11 of Set 12 | saldanha
# Processing Record 12 of Set 12 | bathsheba
# Processing Record 13 of Set 12 | balclutha
# Processing Record 14 of Set 12 | vakhrushev
# Processing Record 15 of Set 12 | parabel
# Processing Record 16 of Set 12 | tommot
# Processing Record 17 of Set 12 | yako
# Processing Record 18 of Set 12 | coquimbo
# Processing Record 19 of Set 12 | namie
# Processing Record 20 of Set 12 | san ignacio
# Processing Record 21 of Set 12 | east london
# Processing Record 22 of Set 12 | cayenne
# Processing Record 23 of Set 12 | kuruman
# Processing Record 24 of Set 12 | santa luzia
# Processing Record 25 of Set 12 | victoria
# Processing Record 26 of Set 12 | guantanamo
# Processing Record 27 of Set 12 | pyaozerskiy
# Processing Record 28 of Set 12 | tromso
# Processing Record 29 of Set 12 | bairiki
# Processing Record 30 of Set 12 | ouanaminthe
# Processing Record 31 of Set 12 | saint george
# Processing Record 32 of Set 12 | bayir
# Processing Record 33 of Set 12 | port hope
# Processing Record 34 of Set 12 | isangel
# Processing Record 35 of Set 12 | iracoubo
# Processing Record 36 of Set 12 | gwadar
# Processing Record 37 of Set 12 | zwedru
# Processing Record 38 of Set 12 | nelson bay
# Processing Record 39 of Set 12 | belyy yar
# Processing Record 40 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 12 | okato
# Processing Record 42 of Set 12 | upington
# Processing Record 43 of Set 12 | ilave
# Processing Record 44 of Set 12 | kaitangata
# Processing Record 45 of Set 12 | san joaquin
# Processing Record 46 of Set 12 | manicore
# Processing Record 47 of Set 12 | araouane
# Processing Record 48 of Set 12 | tete
# Processing Record 49 of Set 12 | bereda
# Processing Record 50 of Set 12 | iqaluit
# Processing Record 51 of Set 12 | bressanone
# Processing Record 52 of Set 12 | rennes
# Processing Record 53 of Set 12 | nabire
# Processing Record 54 of Set 12 | chuy
# Processing Record 55 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 56 of Set 12 | chern
# Processing Record 57 of Set 12 | miracema do tocantins
# Processing Record 58 of Set 12 | mount gambier
# Processing Record 59 of Set 12 | saint-germain-de-grantham
# Processing Record 60 of Set 12 | belaya gora
# Processing Record 1 of Set 13 | kovdor
# Processing Record 2 of Set 13 | mishan
# Processing Record 3 of Set 13 | kulob
# Processing Record 4 of Set 13 | brae
# Processing Record 5 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 13 | seit
# City not found. Skipping...
# Processing Record 8 of Set 13 | marawi
# Processing Record 9 of Set 13 | atambua
# Processing Record 10 of Set 13 | noumea
# Processing Record 11 of Set 13 | poum
# Processing Record 12 of Set 13 | bridlington
# Processing Record 13 of Set 13 | bochnia
# Processing Record 14 of Set 13 | mosquera
# Processing Record 15 of Set 13 | cap malheureux
# Processing Record 16 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 13 | usinsk
# Processing Record 18 of Set 13 | wakefield
# Processing Record 19 of Set 13 | san antero
# Processing Record 20 of Set 13 | hermanus
# Processing Record 21 of Set 13 | nanortalik
# Processing Record 22 of Set 13 | vestmanna
# Processing Record 23 of Set 13 | dingle
# Processing Record 24 of Set 13 | lakatoro
# Processing Record 25 of Set 13 | dolores
# Processing Record 26 of Set 13 | xining
# Processing Record 27 of Set 13 | wagar
# Processing Record 28 of Set 13 | fort wellington
# Processing Record 29 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 13 | port-gentil
# Processing Record 31 of Set 13 | sao gabriel da cachoeira
# Processing Record 32 of Set 13 | grindavik
# Processing Record 33 of Set 13 | komsomolskiy
# Processing Record 34 of Set 13 | voh
# Processing Record 35 of Set 13 | kalmunai
# Processing Record 36 of Set 13 | manzhouli
# Processing Record 37 of Set 13 | izhmorskiy
# Processing Record 38 of Set 13 | vila franca do campo
# Processing Record 39 of Set 13 | na wa
# Processing Record 40 of Set 13 | san vicente
# Processing Record 41 of Set 13 | shubarkuduk
# Processing Record 42 of Set 13 | airai
# Processing Record 43 of Set 13 | shimoda
# Processing Record 44 of Set 13 | mosetse
# Processing Record 45 of Set 13 | jizan
# Processing Record 46 of Set 13 | maltahohe
# Processing Record 47 of Set 13 | katsuura
# Processing Record 48 of Set 13 | kaseda
# Processing Record 49 of Set 13 | mwinilunga
# Processing Record 50 of Set 13 | kamp-lintfort
# Processing Record 51 of Set 13 | nuuk
# Processing Record 52 of Set 13 | chernyshevskiy
# Processing Record 53 of Set 13 | talcher
# Processing Record 54 of Set 13 | impfondo
# Processing Record 55 of Set 13 | santa maria
# Processing Record 56 of Set 13 | biltine
# Processing Record 57 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 58 of Set 13 | port keats
# Processing Record 59 of Set 13 | kohima
# Processing Record 60 of Set 13 | sredneuralsk
# Processing Record 1 of Set 14 | likasi
# Processing Record 2 of Set 14 | skelleftea
# Processing Record 3 of Set 14 | alekseyevsk
# Processing Record 4 of Set 14 | yevsino
# Processing Record 5 of Set 14 | kholmogory
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Kabinda      CD  -6.1333   24.4833     67.89        84
# 1              Sassandra      CI   4.9500   -6.0833     79.20        89
# 2  Navalmoral De La Mata      ES  39.8916   -5.5406     56.26        54
# 3                Kachiry      KZ  53.0675   76.1036     34.23        97
# 4           Kruisfontein      ZA -34.0033   24.7314     60.01        94
# 5             Nouakchott      MR  18.0858  -15.9785     75.20        57
# 6              Cape Town      ZA -33.9258   18.4232     62.60        77
# 7              Batsfjord      NO  70.6345   29.7185     33.80        93
# 8                    Vao      NC -22.6667  167.4833     76.21        66
# 9                  Ipubi      BR  -7.6519  -40.1489     79.21        52
#
#    Cloudiness  Wind Speed Current Description
# 0          43        3.29    scattered clouds
# 1          42        4.83    scattered clouds
# 2           0        1.41           clear sky
# 3         100       14.61     overcast clouds
# 4         100        4.00          light rain
# 5           7       18.41           clear sky
# 6          20       18.41          few clouds
# 7          75        5.75       broken clouds
# 8          94       20.20     overcast clouds
# 9          82        3.20       broken clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")

# %%
url = f'https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}'
city_url = url+"&q=toronto"
requests.get(city_url).json()
# Out:
# {'coord': {'lon': -79.4163, 'lat': 43.7001},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 285.47,
#   'feels_like': 283.67,
#   'temp_min': 284.15,
#   'temp_max': 286.48,
#   'pressure': 1020,
#   'humidity': 35},
#  'visibility': 10000,
#  'wind': {'speed': 1.89, 'deg': 230, 'gust': 2.32},
#  'clouds': {'all': 100},
#  'dt': 1617654940,
#  'sys': {'type': 1,
#   'id': 718,
#   'country': 'CA',
#   'sunrise': 1617619887,
#   'sunset': 1617666521},
#  'timezone': -14400,
#  'id': 6167865,
#  'name': 'Toronto',
#  'cod': 200}
